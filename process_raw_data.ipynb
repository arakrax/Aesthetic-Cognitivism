# %% [markdown]
# use for testing process_raw_data.py

# %%
import process_raw_data as main
import pandas as pd
import os

# here we just use the first file to test the code
files = os.listdir(main.RAW_DATA_PATH)
file_name = f'{main.RAW_DATA_PATH}/{files[0]}'

# %%
file_name
# Out:
# '/Users/mxy/Desktop/study/dsProject/data/raw/Art_exhibitions_gale.csv'

# %%
df = pd.read_csv(file_name)

df.head(5)
# Out:
#                       Author  \
# 0          Collings, Matthew
# 1       Taylor, John Russell
# 2               Warhol, Andy
# 3  Campbell-Johnston, Rachel
# 4       Taylor, John Russell
#
#                                                Title Publication         Date  \
# 0                          My life as a sitting duck   The Times  2006-Jun-14
# 1  If it takes an ear-bashing on the radio to get...   The Times  2005-Mar-23
# 2                 Here's looking at me, myself and I   The Times  2005-Feb-16
# 3                    Sensation! It's paint on canvas   The Times  2005-Jan-26
# 4                               Bright October light   The Times  2004-Nov-24
#
#              Place                                          Full_text  \
# 0  London, England  My life as a sitting duck\nAs both artist and ...
# 1  London, England  ARTS 1\nIf it takes an ear-bashing on the radi...
# 2  London, England  ARTS\nHere's looking at me, myself and I\nvisu...
# 3  London, England  2 ARTS\nSensation! It's paint on canvas\nwisim...
# 4  London, England  ARTS 1\nht October\nexhibition John Russell Ta...
#
#                                                  URL
# 0  https://link.gale.com/apps/doc/IF0502836523/TT...
# 1  https://link.gale.com/apps/doc/IF0502588429/TT...
# 2  https://link.gale.com/apps/doc/IF0502733807/TT...
# 3  https://link.gale.com/apps/doc/IF0502727758/TT...
# 4  https://link.gale.com/apps/doc/IF0502578704/TT...

# %% [markdown]
# ### What we need to process?
# The URL column is used for tracing and will not used for model training, so we don't discuss it.
#
#     Author, Publication，Place: Remove the leading and trailing spaces and convert to title format.
#
#     Title: remove non English character.
#
#     Date: convert to '2006-01-14' format.
#
#     Full_text: remove all HTML tags, remove HTTP links, remove non English characters, make all letters lowercase, remove extra spaces

# %%
main.run()
# Out:
# Art_exhibitions_gale.csv: Start to clean data
# Art_exhibitions_gale.csv: Data cleaning completed
# Concerts_gale.csv: Start to clean data
# Concerts_gale.csv: Data cleaning completed
# Theater_gale.csv: Start to clean data
# Theater_gale.csv: Data cleaning completed
# Operas_gale.csv: Start to clean data
# Operas_gale.csv: Data cleaning completed
# Books_gale.csv: Start to clean data
# Books_gale.csv: Data cleaning completed
# Dance_gale.csv: Start to clean data
# Dance_gale.csv: Data cleaning completed
# Poetry_gale.csv: Start to clean data
# Poetry_gale.csv: Data cleaning completed

# %%
processed_files = os.listdir(main.PROCESSED_DATA_PATH)
processed_file_name = f'{main.PROCESSED_DATA_PATH}/processed_{file_name}'

processed_df = pd.read_csv(processed_file_name)
processed_df.head(5)
# Out:
#   Cell In[6], line 2
#     processed_file_name = f'{main.PROCESSED_DATA_PATH}/{processed_{file_name}}'
#      ^
# SyntaxError: f-string: invalid syntax. Perhaps you forgot a comma?
