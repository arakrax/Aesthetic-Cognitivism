# %% [markdown]
# # Word Frequency Analysis and OCR Correction
#
# This notebook performs a large-scale word frequency analysis on a corpus of text files (CSV format). It is designed to handle large datasets efficiently using multiprocessing.
#
# **Key Goals:**
# 1.  **Count Words:** Calculate the frequency of every unique word across the entire corpus.
# 2.  **Identify Unknowns:** Compare the found words against a "known" dictionary (`complete_wordlist.pkl`) to isolate potential misspellings or OCR errors.
# 3.  **Analyze OCR Errors:** Use the list of unknown words to identify common OCR patterns (e.g., "wv" instead of "w").
# 4.  **Develop Patches:** Create and test regex-based "patches" to automatically fix these systematic errors.
#
# **Methodology:**
# -   **Parallel Processing:** Uses `multiprocessing` to count words in parallel across multiple CPU cores.
# -   **Streaming:** Uses a generator to load and process files in chunks, keeping memory usage low.
# -   **Regex Cleaning:** Applies targeted regular expressions to correct specific OCR artifacts found in the analysis.

# %%
import glob
import pandas as pd
import re
from collections import Counter
from datasets import load_dataset
import os # To get the number of CPU cores
from tqdm import tqdm
import multiprocessing
import pickle

# %%
# This regex will extract words, including those with apostrophes (e.g., "don't", "artist's").
# It excludes standalone punctuation and numbers mixed with symbols.
word_counter_regex = re.compile(r"\b[a-zA-Z'0-9]+\b")

# Path to the directory containing the raw CSV data files
DATA_DIR_PATH = './Data/'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # This regex will extract words, including those with apostrophes (e.g., "don't", "artist's").
#       2 # It excludes standalone punctuation and numbers mixed with symbols.
# ----> 3 word_counter_regex = re.compile(r"\b[a-zA-Z'0-9]+\b")
#       5 # Path to the directory containing the raw CSV data files
#       6 DATA_DIR_PATH = './Data/'
#
# NameError: name 're' is not defined

# %% [markdown]
# ### 1. Parallel Word Counting
# The following functions define the parallel processing logic. `worker_word_counter` is the function that runs on each CPU core, processing a specific batch of text.

# %%
def worker_word_counter(job_tuple):
    """
    Worker function for multiprocessing.
    Counts words in a batch of texts and passes the 'is_last_batch' flag through.
    
    Args:
        job_tuple (tuple): (list_of_texts, is_last_batch_boolean)
        
    Returns:
        tuple: (Counter object with word counts, is_last_batch_boolean)
    """
    # 1. Unpack the job
    texts, is_last_batch_flag = job_tuple
    
    batch_counter = Counter()
    
    for text in texts:
        text_counter = Counter()
        if isinstance(text, str):
            # Use the GLOBAL regex to find all words in the text
            # Convert to lowercase to ensure case-insensitive counting
            words = word_counter_regex.findall(text.lower())
            text_counter.update(words)
        batch_counter.update(text_counter)
        
    # 2. Return the result AND the flag so the main process knows when a file is finished
    return (batch_counter, is_last_batch_flag)

# %%
def get_file_list(directory_path, file_extension="csv"):
    """
    Retrieves a list of all files with a specific extension in a directory.
    Exits the script if no files are found.
    """
    
    file_pattern = os.path.join(directory_path, "*." + file_extension) # e.g., './Data/*.csv'

    print(f"Finding all files matching: {file_pattern}")
    all_files = glob.glob(file_pattern)
    print(f"Found {len(all_files)} files to process.")

    if not all_files:
        print(f"Error: No files found. Check your DATA_DIR_PATH ({directory_path}) and file extension ({file_extension}).")
        exit() # Exit the script if no files are found
    
    return all_files, len(all_files)

# %% [markdown]
# ### 2. Data Streaming
# To avoid loading huge amount of data into RAM, we use a **generator**. This function yields small chunks (batches) of text one by one. The multiprocessing pool consumes these batches as they are yielded.

# %%
def batch_generator(file_list, chunk_size=1000, text_column="Full_text"):
    """
    Generator function. Loads one file at a time and yields 
    its texts in batches. This ensures we only hold one file's worth of data
    in memory at a time.
    """
    print("Batch Generator: Starting up...")
    
    for filename in file_list:
        try:
            # Load the file silently using Hugging Face datasets (efficient memory mapping)
            raw_dataset = load_dataset('csv', data_files=filename) 
            
            texts = raw_dataset['train'][text_column]
            total_texts_in_file = len(texts)
            
            if total_texts_in_file == 0:
                # Special case: file is empty, yield one "last_batch" flag to keep progress bar in sync
                yield ([], True)
                continue

            # Slice the data into chunks
            for i in range(0, total_texts_in_file, chunk_size):
                batch_of_texts = texts[i:i + chunk_size]
                
                # Check if this is the last batch for this specific file
                is_last_batch = (i + chunk_size >= total_texts_in_file)
                
                # Yield the batch AND the flag
                yield (batch_of_texts, is_last_batch)
                
        except Exception as e:
            # Still log errors, but skip the file so the whole process doesn't crash
            print(f"\n[Generator] Error processing file {filename}: {e}\n")
            # Yield a "done" flag for this file so the pbar ticks
            yield ([], True) 
            continue

# %% [markdown]
# ### 3. Main Execution Driver
# This function orchestrates the entire process. It sets up the multiprocessing pool, feeds it data from the generator, and aggregates the results into a single `final_counts` dictionary.

# %%
# ...existing code...
def driver_word_frequency(data_dir_path=None, batch_size=1000):
    """
    Main driver function.
    1. Finds files.
    2. Sets up multiprocessing pool.
    3. Aggregates results from workers.
    """
    all_files, file_count = get_file_list(data_dir_path, file_extension="csv")
    try:
        # Determine number of cores to use (leave 2 free for system stability)
        num_cores = max(1, os.cpu_count() - 2) 
        final_counts = Counter()
        
        # Create the generator ITSELF. (This does NOT load any files yet!)
        job_iterator = batch_generator(all_files, chunk_size=batch_size)

        print(f"Starting processing pool with {num_cores} workers...")
        
        with multiprocessing.Pool(processes=num_cores) as pool:
            
            # imap_unordered is faster as it yields results as soon as they are ready,
            # regardless of the order they were submitted.
            results_iterator = pool.imap_unordered(worker_word_counter, job_iterator)
            
            # --- Progress Bar ---
            with tqdm(total=file_count, desc="Processing files") as pbar:
                for batch_counter, is_last_flag in results_iterator:
                    
                    # 1. Do the reduce step (merge batch counts into global counts)
                    final_counts.update(batch_counter)
                    
                    # 2. Update the bar ONLY when a file is completely done
                    if is_last_flag:
                        pbar.update(1)
            
        print("...Processing complete.")

        return final_counts
        
    except Exception as e:
        print(f"An error occurred in the main block: {e}")
# ...existing code...

# %%
final_counts = driver_word_frequency(data_dir_path=DATA_DIR_PATH)
# Out:
# Finding all files matching: ./Data/*.csv
# Found 7 files to process.
# Starting processing pool with 4 workers...
# Batch Generator: Starting up...
# Processing files: 100%|██████████| 7/7 [00:03<00:00,  1.79it/s]
# ...Processing complete.

# %%
print(final_counts.most_common(100))
print(final_counts.total())
print(len(final_counts))
# Out:
# [('the', 1719250), ('of', 984369), ('and', 760102), ('a', 612475), ('in', 531746), ('to', 519167), ('is', 351825), ('by', 232014), ('it', 208198), ('that', 204275), ('with', 202987), ('was', 197162), ('as', 197064), ('for', 194026), ('his', 171659), ('at', 158738), ('mr', 144961), ('which', 140692), ('on', 138260), ('but', 136189), ('be', 131597), ('he', 114235), ('not', 112796), ('this', 110380), ('an', 108419), ('from', 105573), ('are', 101199), ('has', 97488), ('her', 91688), ('one', 79683), ('have', 77411), ('its', 72505), ('who', 68342), ('more', 67422), ('s', 64982), ('miss', 63013), ('all', 62500), ('music', 62342), ('there', 61087), ('were', 59699), ('their', 58154), ('so', 56800), ('or', 56410), ('i', 55348), ('will', 53839), ('first', 52751), ('they', 52656), ('been', 52099), ('theatre', 51092), ('than', 50927), ('we', 50425), ('she', 50355), ('no', 49462), ('had', 44771), ('two', 43758), ('some', 42666), ('new', 42159), ('last', 40343), ('most', 40312), ('when', 39455), ('work', 38880), ('hall', 38539), ('very', 38053), ('concert', 37073), ('well', 35878), ('play', 34611), ('if', 33706), ('into', 32732), ('other', 32470), ('only', 32333), ('much', 31895), ('performance', 31595), ('out', 30832), ('would', 30765), ('orchestra', 30171), ('too', 30082), ('played', 29474), ('them', 29423), ('part', 28977), ('good', 28793), ('what', 28583), ('london', 28392), ('time', 28115), ('little', 27857), ('may', 27413), ('him', 27368), ('though', 27105), ('programme', 26870), ('can', 26550), ('these', 26509), ('like', 26353), ('night', 26195), ('made', 25729), ('up', 25315), ('such', 25250), ('even', 24984), ('great', 24522), ('also', 23962), ('about', 23338), ('symphony', 22660)]
# 25930337
# 903130

# %%
# Save final_counts to a text file sorted highest-to-lowest by count
output_path = os.path.join(DATA_DIR_PATH, "word_counts_sorted.txt")

with open(output_path, "w", encoding="utf-8") as f:
    # most_common() already returns (word, count) sorted desc by count
    for word, count in final_counts.most_common():
        f.write(f"{count}\t{word}\n")

print(f"Saved {len(final_counts)} unique tokens to: {output_path}")
# Out:
# Saved 903130 unique tokens to: ./Data/word_counts_sorted_with_numbers.txt

# %% [markdown]
# ### 4. Dictionary Comparison
# Now that we have the raw word counts, we compare them against a "known" dictionary (`complete_wordlist.pkl`). This allows us to separate valid words from potential errors.

# %%
COMPLETE_WORDLIST = set()
# Choose a wordlist
WORDLIST_NAME = 'complete_wordlist.pkl' 
#WORDLIST_NAME = 'artist_wordlist.pkl'
DICTIONARY_DATA_DIR = './Dictionary_data/'

# %%
with open(DICTIONARY_DATA_DIR + WORDLIST_NAME, 'rb') as file:
    COMPLETE_WORDLIST = pickle.load(file)
print("Total unique words loaded:", len(COMPLETE_WORDLIST))
# Out:
# Total unique words loaded: 502183

# %% [markdown]
# ### 5. Analyzing Unknown Words
# We isolate the words that were *not* found in our dictionary. These are likely to be:
# 1.  Proper nouns (names, places) not in our list.
# 2.  OCR errors (e.g., "thc" instead of "the").
# 3.  Foreign words.
#
# We save these to a file to inspect them manually and design correction rules.

# %%
final_count_words = set(final_counts.keys())
non_identified_words = final_count_words - COMPLETE_WORDLIST
print(f"Total non-identified words: {len(non_identified_words)}")
print("Sample non-identified words:", list(non_identified_words)[:20])
non_identified_words_counts = Counter({word: final_counts[word] for word in non_identified_words})
# Out:
# Total non-identified words: 799570
# Sample non-identified words: ['pctri', 'dedhouse', 'audieuca', '31al', 'patrty', 'verkldrte', "ffi'cr", 'affec', 'felik', 'instrunmentalists', 'eulow', 'dihiculties', 'exhibitcd', 'onu', 'plentvo', 'itwasno', 'entwinements', 'clodhopperly', '1xa', 'britwell']

# %%
# Save non_identified_words to a text file sorted highest-to-lowest by count
output_path = os.path.join('./', "non_identified_word_counts.txt")

with open(output_path, "w", encoding="utf-8") as f:
    # most_common() already returns (word, count) sorted desc by count
    for word, count in non_identified_words_counts.most_common():
        f.write(f"{count}\t{word}\n")

print(f"Saved {len(final_counts)} unique tokens to: {output_path}")
# Out:
# Saved 845044 unique tokens to: ./non_identified_word_counts.txt

# %%
#Find identified words which are correctly spelled
identified_words = final_count_words & COMPLETE_WORDLIST
print(f"Total identified words: {len(identified_words)}")
print("Sample identified words:", list(identified_words)[:20])

output_path = os.path.join('./', "identified_words_counts.txt")

total_word_count = sum(final_counts.values())
identified_words_counts = {word: final_counts[word] for word in identified_words}

with open(output_path, "w", encoding="utf-8") as f:
    # most_common() already returns (word, count) sorted desc by count
    for word in identified_words:
        f.write(f"{final_counts[word]}\t{word}\n")

print(f"Saved {len(final_counts)} unique tokens to: {output_path}")

DICTIONARY_DATA_DIR = './Dictionary_data/'
output_path = os.path.join(DICTIONARY_DATA_DIR, "identified_words_freq_percentage.pkl")
with open(output_path, 'wb') as file:
    pickle.dump(identified_words_counts, file)
print(f"Saved {len(identified_words_counts)} identified words with frequencies to: {output_path}")
# Out:
# Total identified words: 103471
# Sample identified words: ['tenderly', 'jerkins', 'weald', 'ratter', 'blowings', 'dosser', 'shoring', 'mfr', 'slacking', 'rhapsodizing', 'leavening', 'viewpoints', 'tuned', 'argante', 'bladder', 'regally', 'flexible', 'homier', 'convoluted', 'solita']
# Saved 845044 unique tokens to: ./identified_words_counts.txt
# Saved 103471 identified words with frequencies to: ./Dictionary_data/identified_words_freq_percentage.pkl

# %%
final_counts
# Out:
# Counter({'my': 6925,
#          'life': 15727,
#          'as': 197064,
#          'a': 612475,
#          'sitting': 700,
#          'duck': 182,
#          'both': 19322,
#          'artist': 6450,
#          'and': 760102,
#          'art': 16398,
#          'critic': 1652,
#          'matthew': 902,
#          'collings': 23,
#          'sets': 2114,
#          'himself': 13440,
#          'up': 25315,
#          'to': 519167,
#          'be': 131597,
#          'shot': 750,
#          'by': 232014,
#          'sides': 751,
#          'chris': 473,
#          'mcandrew': 5,
#          'jrtsjla': 1,
#          'aam': 32,
#          'ii': 2702,
#          '0': 3163,
#          'jy': 30,
#          'i': 55348,
#          'ss': 800,
#          'for': 194026,
#          'long': 15513,
#          'time': 28115,
#          "i've": 591,
#          'led': 2864,
#          'double': 3272,
#          'been': 52099,
#          'an': 108419,
#          'writing': 4594,
#          'nearly': 3323,
#          '30': 7623,
#          'years': 17611,
#          'but': 136189,
#          'during': 7292,
#          'that': 204275,
#          'kept': 2656,
#          'studio': 1338,
#          'in': 531746,
#          'exhibitions': 2579,
#          'last': 40343,
#          'week': 10118,
#          'exhibition': 9464,
#          'of': 984369,
#          'abstract': 899,
#          'paintings': 3493,
#          'opened': 3281,
#          'at': 158738,
#          'gallery': 6409,
#          'bond': 1615,
#          'street': 7305,
#          'name': 5446,
#          'is': 351825,
#          'on': 138260,
#          'the': 1719250,
#          'window': 911,
#          'most': 40312,
#          'work': 38880,
#          'sold': 818,
#          'very': 38053,
#          'quickly': 1050,
#          'so': 56800,
#          "there's": 1209,
#          'obviously': 1938,
#          'something': 10240,
#          'there': 61087,
#          "that's": 1112,
#          'working': 2392,
#          'how': 12297,
#          'can': 26550,
#          'this': 110380,
#          'one': 79683,
#          'really': 7043,
#          'ist': 454,
#          'do': 18607,
#          'skills': 377,
#          'inform': 129,
#          'or': 56410,
#          'undermine': 34,
#          'other': 32470,
#          'fact': 8583,
#          "i'm": 1156,
#          'peculiar': 1523,
#          '21': 1448,
#          'million': 583,
#          'people': 9281,
#          'wrong': 2038,
#          'was': 197162,
#          'headline': 95,
#          'which': 140692,
#          'conceived': 1143,
#          'monthly': 91,
#          'columns': 414,
#          'magazine': 255,
#          'modern': 9185,
#          'painters': 1483,
#          'recently': 2606,
#          'it': 208198,
#          'about': 23338,
#          'supposed': 1834,
#          'triumph': 1263,
#          'tate': 628,
#          "modern's": 4,
#          'first': 52751,
#          'five': 5787,
#          'went': 4005,
#          'school': 5860,
#          '1970s': 220,
#          'studied': 1005,
#          'painting': 3198,
#          'formed': 1921,
#          'intellectually': 142,
#          'contemporary': 4364,
#          'world': 10728,
#          'have': 77411,
#          'mindset': 9,
#          'want': 3149,
#          'criticise': 40,
#          'part': 28977,
#          'scene': 11972,
#          'often': 9340,
#          'find': 7115,
#          'insipid': 183,
#          'feeble': 418,
#          'objects': 863,
#          "we're": 329,
#          'marvel': 272,
#          'strangulated': 17,
#          'critical': 951,
#          'commentary': 362,
#          'thafs': 71,
#          'justify': 618,
#          'them': 29423,
#          'has': 97488,
#          'described': 2446,
#          'over': 15912,
#          'outlandish': 66,
#          'hilarious': 252,
#          'horri': 5,
#          'ble': 499,
#          'kamikaze': 3,
#          'free': 4130,
#          'fall': 2451,
#          'some': 42666,
#          'extent': 1521,
#          'expresses': 341,
#          'polemicise': 1,
#          'evangelise': 1,
#          'plainly': 556,
#          'ploddingly': 8,
#          'describe': 723,
#          'things': 8606,
#          'make': 16067,
#          'jokes': 950,
#          'hurt': 204,
#          "people's": 516,
#          'feelings': 1195,
#          'ifs': 281,
#          'not': 112796,
#          'just': 12999,
#          'venting': 15,
#          'ultimate': 412,
#          'aim': 1113,
#          'get': 5876,
#          'behind': 3436,
#          'describing': 322,
#          'superficial': 569,
#          'stuff': 898,
#          'what': 28583,
#          'object': 1820,
#          'saying': 1179,
#          'also': 23962,
#          'sensibility': 785,
#          'demystify': 7,
#          'reveal': 981,
#          'ordinary': 2383,
#          'educated': 256,
#          'readers': 936,
#          'may': 27413,
#          'aspects': 937,
#          'operates': 59,
#          'quite': 12854,
#          'simply': 2726,
#          'never': 13644,
#          'occurred': 530,
#          'many': 18714,
#          'think': 5225,
#          'artists': 6282,
#          'live': 3234,
#          'like': 26353,
#          'siri': 7,
#          'hustvedf': 1,
#          's': 64982,
#          'novels': 1357,
#          'you': 17381,
#          'see': 9499,
#          'beautiful': 7287,
#          'model': 1216,
#          "you're": 439,
#          'inspired': 2144,
#          'somehow': 1010,
#          'tumble': 131,
#          'into': 32732,
#          'bed': 964,
#          'with': 202987,
#          'subsequent': 667,
#          'artwork': 28,
#          'express': 1398,
#          'es': 1629,
#          'all': 62500,
#          'complexity': 387,
#          'your': 3749,
#          'statement': 1115,
#          'go': 6908,
#          'experienced': 1020,
#          'anybody': 407,
#          'who': 68342,
#          'signs': 1017,
#          'fantasy': 1627,
#          'would': 30765,
#          'able': 5244,
#          'believe': 2862,
#          'boringness': 4,
#          'being': 19544,
#          'painter': 2165,
#          'actually': 1918,
#          'involves': 357,
#          'thing': 7225,
#          "they're": 337,
#          'mine': 935,
#          '50': 3026,
#          'collaborations': 43,
#          'wife': 6652,
#          'mosaicist': 1,
#          'emma': 444,
#          'biggs': 35,
#          'she': 50355,
#          'conceives': 74,
#          'layouts': 3,
#          'thinks': 843,
#          'colours': 3027,
#          'we': 50425,
#          'share': 1714,
#          'equal': 2325,
#          'billing': 61,
#          'vary': 363,
#          'roles': 1500,
#          'paints': 350,
#          'question': 3269,
#          'her': 91688,
#          'decisions': 100,
#          'colour': 9072,
#          'blind': 849,
#          'were': 59699,
#          'unable': 989,
#          'continued': 1212,
#          'page': 2378,
#          '16': 2052,
#          'newpage': 184,
#          '4': 5163,
#          'comnmed': 1,
#          'from': 105573,
#          'why': 4616,
#          'certain': 6428,
#          'sections': 1307,
#          'are': 101199,
#          'way': 16652,
#          'they': 52656,
#          'sometimes': 6166,
#          'only': 32333,
#          'getting': 1540,
#          'logic': 503,
#          'after': 20428,
#          'finished': 1991,
#          'perhaps': 13604,
#          'misleading': 117,
#          'since': 10630,
#          "aren't": 181,
#          'ideas': 3323,
#          'purely': 1336,
#          'visual': 864,
#          'hand': 7494,
#          'such': 25250,
#          'y': 4416,
#          'intelligence': 1719,
#          'look': 4747,
#          'good': 28793,
#          'focus': 877,
#          'seem': 6209,
#          'light': 8071,
#          'turned': 3033,
#          'inside': 997,
#          'carefully': 1661,
#          'structured': 102,
#          'late': 5916,
#          'medieval': 612,
#          'frescos': 6,
#          'relate': 224,
#          'embody': 124,
#          'values': 890,
#          'important': 4622,
#          'serious': 3724,
#          'thrown': 1012,
#          'out': 30832,
#          'past': 4859,
#          '15': 6003,
#          'striven': 42,
#          'become': 5581,
#          'more': 67422,
#          'popular': 5595,
#          'entertainment': 3421,
#          'own': 20882,
#          'got': 3433,
#          'far': 10919,
#          'when': 39455,
#          'back': 8320,
#          'ma': 1329,
#          'tutors': 15,
#          'said': 9270,
#          'needed': 2463,
#          'idea': 4797,
#          'through': 14659,
#          'keep': 2760,
#          'piling': 47,
#          'different': 6848,
#          'ones': 1651,
#          'merely': 3441,
#          'resulted': 279,
#          'meltdown': 21,
#          'because': 11641,
#          'experience': 3816,
#          'observer': 186,
#          'allowed': 2972,
#          'too': 30082,
#          'possibilities': 788,
#          'these': 26509,
#          'though': 27105,
#          'separated': 499,
#          'aspect': 1016,
#          'judging': 388,
#          'whether': 5479,
#          'right': 7830,
#          'handed': 513,
#          'someone': 1001,
#          'else': 3417,
#          'does': 14193,
#          'prospect': 508,
#          'judged': 1039,
#          'feel': 3820,
#          'am': 2349,
#          'afraid': 655,
#          'yes': 1006,
#          'written': 8600,
#          'previous': 1838,
#          'their': 58154,
#          'ourselves': 755,
#          'thinking': 1134,
#          'conservative': 337,
#          'final': 4995,
#          'flourish': 297,
#          'best': 16477,
#          'review': 682,
#          'times': 6845,
#          'mind': 5748,
#          'powerful': 2494,
#          'convincing': 1195,
#          'maverick': 74,
#          "biggs's": 6,
#          'radiant': 337,
#          'schemes': 305,
#          'brought': 8541,
#          'nervous': 826,
#          'exquisite': 1872,
#          'lurked': 16,
#          'beneath': 948,
#          "collings's": 1,
#          'alarming': 220,
#          'caliban': 132,
#          'persona': 158,
#          'together': 7636,
#          "they've": 83,
#          'rocked': 25,
#          'brilliant': 4482,
#          'reality': 1263,
#          'painful': 516,
#          'meantime': 214,
#          'still': 15107,
#          'dream': 2314,
#          'taken': 7251,
#          'away': 5509,
#          'practice': 1175,
#          'bit': 1969,
#          'post': 1507,
#          'facto': 15,
#          'explaining': 188,
#          'our': 15077,
#          "couldn't": 400,
#          'sureness': 119,
#          'brush': 441,
#          'strokes': 301,
#          'ambitions': 205,
#          'marks': 968,
#          'well': 35878,
#          'need': 4788,
#          'give': 12389,
#          'context': 1060,
#          'whole': 13417,
#          'range': 3271,
#          'come': 8754,
#          'absolute': 889,
#          'certainty': 572,
#          'should': 15744,
#          'where': 14835,
#          'structure': 1676,
#          'concerned': 2276,
#          'deployed': 97,
#          'certainties': 41,
#          'along': 2290,
#          'using': 1359,
#          'doing': 2526,
#          'even': 24984,
#          'if': 33706,
#          'mud': 132,
#          'end': 16857,
#          'result': 4055,
#          'say': 10005,
#          'pretty': 4154,
#          'successful': 5232,
#          'fine': 8874,
#          'society': 9164,
#          'london': 28392,
#          'wl': 559,
#          '020': 2290,
#          '7629': 4,
#          '5116': 8,
#          'until': 6694,
#          'july': 1762,
#          '7': 10585,
#          'arts': 6324,
#          '1': 13553,
#          'takes': 5058,
#          'ear': 2251,
#          'bashing': 28,
#          'radio': 2370,
#          'punters': 82,
#          'show': 10539,
#          'sponsorships': 3,
#          'associations': 366,
#          'between': 15713,
#          'commercial': 510,
#          'bodies': 596,
#          'forprofit': 2,
#          'institutions': 216,
#          'wonder': 1835,
#          'great': 24522,
#          'insistence': 281,
#          'relationship': 1103,
#          'harm': 253,
#          'than': 50927,
#          'day': 11596,
#          'listening': 1115,
#          'programme': 26870,
#          'english': 16124,
#          'music': 62342,
#          'classic': 1568,
#          'fm': 308,
#          'every': 14836,
#          'break': 1318,
#          'records': 1158,
#          'desperate': 619,
#          'sounding': 675,
#          'plug': 34,
#          'lamorna': 28,
#          'birch': 239,
#          'lowry': 86,
#          'salford': 49,
#          'charmed': 201,
#          'hear': 6417,
#          'obscurer': 9,
#          'enthusiasms': 54,
#          'lauded': 24,
#          'skies': 163,
#          'then': 15528,
#          'became': 2611,
#          'increasingly': 413,
#          'irritated': 62,
#          'apparently': 2267,
#          'station': 606,
#          'collaboration': 672,
#          'aural': 220,
#          'combination': 1534,
#          'vaughan': 2158,
#          'williams': 3016,
#          'arnold': 1428,
#          'bax': 577,
#          'et': 1866,
#          'al': 3260,
#          "station's": 10,
#          'appropriate': 1693,
#          'much': 31895,
#          'appreciated': 884,
#          'itself': 8483,
#          'totally': 644,
#          'beguiling': 295,
#          'least': 8072,
#          'anyone': 1525,
#          'taste': 4584,
#          'sort': 4035,
#          'impressionism': 166,
#          'considered': 1869,
#          'slightly': 1927,
#          'bold': 1554,
#          'beginning': 4205,
#          'century': 7689,
#          '1869': 41,
#          '1955': 147,
#          'born': 2066,
#          'cheshire': 62,
#          'christened': 43,
#          'samuel': 1006,
#          'john': 15991,
#          'training': 994,
#          'couple': 2219,
#          'paris': 4181,
#          'he': 114235,
#          'settled': 632,
#          'cornwall': 210,
#          'near': 2683,
#          'newlyn': 24,
#          'took': 5919,
#          'his': 171659,
#          'new': 42159,
#          'home': 6062,
#          'largely': 1583,
#          'differentiate': 63,
#          'already': 6057,
#          'called': 8972,
#          'lionel': 628,
#          'close': 4025,
#          'friend': 2751,
#          'two': 43758,
#          'married': 1629,
#          'couples': 405,
#          'laura': 522,
#          'harold': 1728,
#          'knight': 660,
#          'elizabeth': 2963,
#          'stanhope': 108,
#          'forbes': 569,
#          'painted': 2228,
#          'same': 16139,
#          'landscape': 2517,
#          'impressionist': 259,
#          'lushness': 12,
#          'moderated': 13,
#          'relative': 358,
#          'rigour': 110,
#          'rocky': 169,
#          'cornish': 155,
#          'eloquence': 673,
#          'irritating': 179,
#          'me': 6350,
#          'turns': 2678,
#          'him': 27368,
#          'better': 11068,
#          "don't": 1971,
#          'any': 22194,
#          'rate': 3412,
#          'no': 49462,
#          'current': 1753,
#          'stories': 1426,
#          'interesting': 8394,
#          'bizarre': 455,
#          'common': 2798,
#          'currency': 89,
#          'sixties': 358,
#          'take': 8969,
#          'history': 3736,
#          'evelyne': 13,
#          'axeil': 2,
#          'belgian': 514,
#          'pop': 885,
#          'whose': 12756,
#          'memorable': 1028,
#          'works': 20547,
#          'mayor': 581,
#          'genuine': 2609,
#          'technical': 3584,
#          'innovator': 32,
#          'thought': 5333,
#          'car': 871,
#          'enamel': 48,
#          'plexiglass': 3,
#          'mounting': 260,
#          'aluminium': 25,
#          'course': 8725,
#          'might': 13690,
#          'reply': 315,
#          'wish': 2069,
#          'results': 1376,
#          'haunting': 458,
#          'once': 10076,
#          'kitschy': 4,
#          'agonised': 46,
#          'happily': 1814,
#          'existing': 427,
#          'ghastly': 119,
#          'had': 44771,
#          'intriguing': 449,
#          'know': 5945,
#          'precise': 1084,
#          'circumstances': 1833,
#          "axell's": 1,
#          'death': 5899,
#          '1972': 143,
#          'brusquely': 24,
#          'killed': 655,
#          'drunken': 319,
#          'crash': 206,
#          'undeniably': 193,
#          'puts': 1205,
#          'quandary': 19,
#          'extreme': 1458,
#          'dealing': 537,
#          'problem': 2094,
#          'anyway': 351,
#          'whoever': 169,
#          'heard': 10120,
#          'ica': 219,
#          'seemed': 9197,
#          'its': 72505,
#          'duty': 1115,
#          'wild': 1544,
#          'wacky': 36,
#          'wonderful': 2100,
#          'suitably': 362,
#          'avantgarde': 30,
#          'deathly': 22,
#          'seriousness': 549,
#          'happenings': 78,
#          'expected': 2632,
#          'happen': 987,
#          'particularly': 5997,
#          'openings': 84,
#          'while': 14362,
#          'now': 20569,
#          'institution': 641,
#          'little': 27857,
#          'less': 16983,
#          'purposefully': 71,
#          'silly': 604,
#          'nice': 1326,
#          'estimable': 49,
#          'tradition': 2551,
#          'seems': 10200,
#          'set': 11084,
#          'revival': 3071,
#          'opening': 7288,
#          'becks': 14,
#          'futures': 17,
#          '2005': 88,
#          'case': 5630,
#          'point': 9429,
#          'unfortunately': 1360,
#          'abortive': 55,
#          'happening': 349,
#          'plots': 255,
#          'aplenty': 26,
#          'whispered': 125,
#          'shouted': 114,
#          'house': 11594,
#          'tops': 99,
#          'bottoms': 25,
#          "ica's": 7,
#          'anon': 60,
#          'main': 3472,
#          'plot': 3619,
#          'discussed': 433,
#          'originating': 37,
#          'shortlisted': 19,
#          'lips': 491,
#          'sealed': 109,
#          'subscribe': 45,
#          'pact': 71,
#          'ensuring': 57,
#          'won': 1953,
#          'top': 2600,
#          'prize': 1248,
#          'award': 678,
#          'fund': 1392,
#          '40': 1684,
#          '000': 2571,
#          'plus': 1039,
#          'inconsiderable': 89,
#          '20': 3730,
#          'extra': 1136,
#          'lot': 1888,
#          'divided': 961,
#          'equally': 3374,
#          'among': 11315,
#          'six': 4409,
#          'attempted': 843,
#          'essay': 674,
#          'egalitarianism': 3,
#          'three': 20930,
#          'deemed': 239,
#          'likely': 2410,
#          'win': 950,
#          'fair': 2795,
#          'chance': 2914,
#          'dead': 2754,
#          'against': 5896,
#          'competitions': 152,
#          'horse': 843,
#          'races': 119,
#          "it's": 4232,
#          'winning': 881,
#          'fun': 2764,
#          'race': 713,
#          'entrants': 26,
#          'came': 7808,
#          'bottom': 601,
#          'somebody': 366,
#          'provocative': 208,
#          'reading': 3641,
#          'palm': 223,
#          'lower': 1230,
#          'down': 7890,
#          'young': 17563,
#          "didn't": 959,
#          'courage': 918,
#          'cerith': 1,
#          'wyn': 94,
#          'evans': 937,
#          'veteran': 521,
#          'judge': 1518,
#          'ready': 1721,
#          'indeed': 8127,
#          'eager': 759,
#          'drop': 636,
#          'trousers': 262,
#          'anna': 1141,
#          'sten': 21,
#          'observes': 186,
#          'strait': 54,
#          'laced': 76,
#          'daughter': 3770,
#          'runaway': 86,
#          'daughters': 501,
#          'understand': 1794,
#          'nobody': 1055,
#          'vant': 36,
#          "here's": 114,
#          'looking': 2182,
#          'myself': 625,
#          'throughout': 4553,
#          'andy': 215,
#          'warhol': 62,
#          'produced': 7645,
#          'self': 4606,
#          'portraits': 1603,
#          'russell': 1249,
#          'taylor': 1345,
#          'wonders': 527,
#          'scottish': 2229,
#          'national': 7461,
#          'modem': 1637,
#          'edinburgh': 2654,
#          'before': 16356,
#          "warhol's": 10,
#          'latest': 1955,
#          'done': 7158,
#          'months': 1839,
#          'based': 2872,
#          'photograph': 311,
#          'famous': 3571,
#          'platinum': 32,
#          'wig': 303,
#          'disarray': 29,
#          'transferred': 543,
#          'canvas': 606,
#          'each': 12270,
#          'suffused': 54,
#          'pastel': 435,
#          'shade': 1026,
#          'cases': 853,
#          'pale': 594,
#          'military': 1050,
#          'camouflage': 18,
#          'round': 3728,
#          'ofthe': 1235,
#          "dealer's": 18,
#          'minions': 22,
#          'descended': 137,
#          "isn't": 746,
#          'cried': 119,
#          'probably': 4280,
#          'moving': 2464,
#          '20th': 656,
#          'um': 194,
#          'replied': 183,
#          'anew': 249,
#          'bring': 3596,
#          'rear': 167,
#          "art's": 43,
#          'comprehensive': 596,
#          'portraiture': 268,
#          'career': 2135,
#          'extensive': 451,
#          'proves': 937,
#          'virtually': 589,
#          'everything': 3600,
#          'did': 15143,
#          'industrial': 433,
#          'scale': 2595,
#          'nothing': 9720,
#          'factory': 397,
#          'assembly': 392,
#          '80': 526,
#          'selfportraits': 3,
#          'comes': 6299,
#          'surprise': 1533,
#          'begin': 2145,
#          '1948': 173,
#          '1986': 130,
#          '48': 387,
#          'earliest': 590,
#          'drawings': 3964,
#          'style': 13362,
#          'generally': 3482,
#          'familiar': 5119,
#          'few': 10520,
#          'endless': 339,
#          'production': 12376,
#          'gift': 1371,
#          'booklets': 10,
#          'reusing': 1,
#          'advertisement': 194,
#          'subject': 5671,
#          'shoes': 437,
#          'food': 528,
#          'angels': 488,
#          'recent': 4057,
#          'spate': 52,
#          'chiefly': 1771,
#          'perfectly': 2744,
#          'capable': 1948,
#          'conventional': 1888,
#          'forms': 2217,
#          'beforehe': 2,
#          'exclusively': 693,
#          'photographs': 599,
#          'basis': 867,
#          'touch': 4292,
#          'sophisticated': 747,
#          'naivety': 168,
#          'curiously': 933,
#          'reminiscent': 323,
#          'lucian': 21,
#          'freud': 89,
#          "freud's": 16,
#          'teenage': 202,
#          'makes': 8920,
#          'known': 7515,
#          'edward': 2985,
#          'burra': 30,
#          'surviving': 207,
#          'suggest': 2201,
#          'acquaintance': 758,
#          'york': 3713,
#          'fifties': 186,
#          'juggled': 10,
#          'notably': 1311,
#          'ben': 1344,
#          'intervention': 146,
#          'director': 4194,
#          'shahn': 3,
#          'saul': 103,
#          'steinberg': 75,
#          'whatever': 2405,
#          'models': 529,
#          'portrait': 3465,
#          'hands': 4002,
#          'covering': 233,
#          'eyes': 2467,
#          'extraordinary': 2302,
#          'maturity': 414,
#          'confidence': 1335,
#          'simple': 4490,
#          'maybe': 796,
#          'realised': 210,
#          'closely': 1331,
#          'associated': 1125,
#          'advertising': 173,
#          'let': 4004,
#          'seriously': 1155,
#          'possibly': 1810,
#          'wanted': 1640,
#          'controversial': 169,
#          'newsworthy': 6,
#          'reason': 3988,
#          'change': 2991,
#          'direction': 4061,
#          'radically': 68,
#          'around': 2705,
#          '1962': 177,
#          'date': 1487,
#          "campbell's": 81,
#          'soup': 96,
#          'tins': 315,
#          'photographic': 249,
#          'screenprints': 3,
#          'subjects': 2170,
#          'treatment': 3486,
#          'included': 4164,
#          'marilyn': 175,
#          'monroe': 38,
#          'elvis': 85,
#          'presley': 28,
#          'coca': 14,
#          'cola': 27,
#          'bottles': 138,
#          'related': 534,
#          'images': 948,
#          'road': 2760,
#          'accidents': 221,
#          'following': 2631,
#          'year': 12006,
#          'started': 1366,
#          'apply': 431,
#          'impersonal': 176,
#          'procedures': 55,
#          'image': 896,
#          'hits': 535,
#          'distinctive': 948,
#          'photo': 94,
#          'booth': 346,
#          'picture': 5520,
#          'blown': 207,
#          'printed': 836,
#          'tinted': 117,
#          'blue': 2053,
#          'version': 4942,
#          'turquoise': 51,
#          'another': 13150,
#          'clear': 6151,
#          'implication': 149,
#          'could': 20035,
#          'mechanically': 71,
#          'reproduced': 317,
#          'ad': 1386,
#          'infinitum': 7,
#          'silk': 768,
#          'screen': 792,
#          'wore': 827,
#          'foundation': 753,
#          'ars': 139,
#          'process': 1264,
#          'original': 6858,
#          'silkscreen': 1,
#          'strip': 198,
#          'instructions': 162,
#          'transfer': 316,
#          'traditional': 1775,
#          'standards': 869,
#          'proper': 2311,
#          'present': 11885,
#          'machine': 622,
#          'ruled': 159,
#          'later': 5993,
#          'suing': 26,
#          'assistants': 114,
#          'gerald': 1579,
#          'malanga': 1,
#          'bridget': 96,
#          'polk': 20,
#          'taking': 3138,
#          'literally': 471,
#          'making': 6181,
#          'asked': 1489,
#          'inconsistent': 83,
#          'stated': 979,
#          'principles': 609,
#          'ah': 851,
#          'money': 2375,
#          'doubt': 5247,
#          'role': 3315,
#          'mechanical': 784,
#          'sincerely': 206,
#          'held': 3627,
#          "what's": 372,
#          ...})

# %% [markdown]
# ### 6. Filtering Noise
# Many "unknown" words are just numbers or measurements (e.g., "1990", "5kg"). We filter these out to focus on textual errors.

# %%
words_with_digits = Counter()

endings_1 = ['s', 'd', 'p', 'm']
endings_2 = ['th', 'pm', 'am', 'nd', 'rd', 'st', 'ft', 'kg', 'oz', 'km', 'kw', 'lb']
endings_3 = ['hrs']
endings_4 = ['mins']

for word, count in final_counts.most_common():
    digits = [c.isdigit() for c in word]
    if all(digits):
        continue
    if all(digits[:-1]) and word[-1:] in endings_1:
        continue
    if all(digits[:-2]) and word[-2:] in endings_2:
        continue
    if all(digits[:-3]) and word[-3:] in endings_3:
        continue
    if all(digits[:-4]) and word[-4:] in endings_4:
        continue
    if any(digits):
        words_with_digits.update({word : count})
print(len(words_with_digits))
# Out:
# 51670

# %%
output_path = os.path.join('./', "words_with_digits.txt")
with open(output_path, "w", encoding="utf-8") as f:
    # most_common() already returns (word, count) sorted desc by count
    for word, count in words_with_digits.most_common():
        f.write(f"{count}\t{word}\n")

# %%
NER_WORDLIST = set()
NER_WORDLIST_NAME = 'ner_wordlist.pkl' 
DICTIONARY_DATA_DIR = './Dictionary_data/'
with open(DICTIONARY_DATA_DIR + NER_WORDLIST_NAME, 'rb') as file:
    NER_WORDLIST = pickle.load(file)
print("Total unique words loaded:", len(NER_WORDLIST))
# Out:
# Total unique words loaded: 14874

# %%
misspelled_without_digits = non_identified_words.difference(words_with_digits, NER_WORDLIST)

# %%
'\'' in "beethoven'"
# Out:
# True

# %%
print(sorted(list(NER_WORDLIST)[:100]))
# Out:
# ['addis', 'alekseyev', 'alperon', 'altarpiece', 'amy', 'arabia', 'armagnac', 'aurand', 'ayman', 'aziz', 'baroque', 'bastian', 'bologna', 'branamour', 'brendan', 'british', 'canberra', 'cavaliers', 'clemens', 'clijsters', 'das', 'dunem', 'dwarka', 'egypt-gaza', 'elbaradei', 'everblades', 'fernet-branca', 'flannery', 'gamboa', 'gan-based', 'guinea', 'gulzar', 'hassell', 'hetty', 'ibb', 'internacional', 'interpol', 'jacky', 'jafar', 'jalalabad', 'jamestown', 'jinan', 'jirikan', 'joaquín', 'johnson-morris', 'kallio', 'karameh', 'khurshid', 'league-nawaz', 'lithuania', 'marcelo', 'marcinelle', 'mbabane', 'mcqueen', 'medicine', 'mirnyi', 'moi', 'monrovia', 'moyo', 'napoli', 'navy', 'nechvatal', 'neverland', 'nozari', 'nuristan', 'oktay', 'oval', 'pacheco', 'palaeocene', 'perrier', 'peugeot', 'printemps', 'pro-moscow', 'razzano', 'reims', 'reno', 'revava', 'rush', 'ryan', 'rødberg', 'sanha', 'scharping', 'selhurst', 'solaiman', 'somaieh', 'southwark', 'spare-time', 'sudeten', 'suyono', 't-neck', 'theta', 'tianjin', 'tiger', 'uji', 'ulus', 'weisz', 'whitney', 'yokohama', 'zeid', 'zoran']

# %%
from datasets import load_dataset

ds = load_dataset("wiki_bio")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# wiki_bio.py: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 from datasets import load_dataset
# ----> 3 ds = load_dataset("wiki_bio")
#
# File ~/python_venv/andreas/lib/python3.11/site-packages/datasets/load.py:1392, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1387 verification_mode = VerificationMode(
#    1388     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1389 )
#    1391 # Create a dataset builder
# -> 1392 builder_instance = load_dataset_builder(
#    1393     path=path,
#    1394     name=name,
#    1395     data_dir=data_dir,
#    1396     data_files=data_files,
#    1397     cache_dir=cache_dir,
#    1398     features=features,
#    1399     download_config=download_config,
#    1400     download_mode=download_mode,
#    1401     revision=revision,
#    1402     token=token,
#    1403     storage_options=storage_options,
#    1404     **config_kwargs,
#    1405 )
#    1407 # Return iterable dataset in case of streaming
#    1408 if streaming:
#
# File ~/python_venv/andreas/lib/python3.11/site-packages/datasets/load.py:1132, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1130 if features is not None:
#    1131     features = _fix_for_backward_compatible_features(features)
# -> 1132 dataset_module = dataset_module_factory(
#    1133     path,
#    1134     revision=revision,
#    1135     download_config=download_config,
#    1136     download_mode=download_mode,
#    1137     data_dir=data_dir,
#    1138     data_files=data_files,
#    1139     cache_dir=cache_dir,
#    1140 )
#    1141 # Get dataset builder class
#    1142 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/python_venv/andreas/lib/python3.11/site-packages/datasets/load.py:1031, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1026             if isinstance(e1, FileNotFoundError):
#    1027                 raise FileNotFoundError(
#    1028                     f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1029                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1030                 ) from None
# -> 1031             raise e1 from None
#    1032 else:
#    1033     raise FileNotFoundError(f"Couldn't find any data file at {relative_to_absolute_path(path)}.")
#
# File ~/python_venv/andreas/lib/python3.11/site-packages/datasets/load.py:989, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     981 try:
#     982     api.hf_hub_download(
#     983         repo_id=path,
#     984         filename=filename,
#    (...)
#     987         proxies=download_config.proxies,
#     988     )
# --> 989     raise RuntimeError(f"Dataset scripts are no longer supported, but found {filename}")
#     990 except EntryNotFoundError:
#     991     # Use the infos from the parquet export except in some cases:
#     992     if data_dir or data_files or (revision and revision != "main"):
#
# RuntimeError: Dataset scripts are no longer supported, but found wiki_bio.py

# %% [markdown]
# ### 7. OCR Correction Logic
# Based on the analysis of the "unknown" words, we define specific regex rules to fix common OCR mistakes.
#
# *   **Aggressive Patches:** Fix systematic character replacements (e.g., `wv` -> `w`).
# *   **Common Patches:** Fix specific high-frequency misspelled words (e.g., `thc` -> `the`).

# %%
def apply_aggressive_ocr_patches(text):
    """
    Applies regex-based fixes for systematic OCR errors (wv->w, rn->m)
    and high-frequency specific word errors found in the dataset.
    """
    # --- 1. Systematic 'w' and 'm' Fixes ---
    # Fix "wv" or "vw" anywhere (e.g. "twvo", "wvas") -> likely "w"
    text = re.sub(r'wv|vw', 'w', text, flags=re.IGNORECASE)
    # Fix "wl" at start of word (e.g. "wlhich", "wlho") -> likely "w"
    text = re.sub(r'\bwl', 'w', text, flags=re.IGNORECASE)
    # Fix "w" being read as "v" in specific common words (e.g., "vhich" -> "which")
    text = re.sub(r'\bv(hich|ith|hen|here|ho|hose|ould)\b', r'w\1', text, flags=re.IGNORECASE)
    
    # Fix "mn" or "nm" at start (e.g. "mnore") -> likely "m"
    text = re.sub(r'\b[mn]m', 'm', text, flags=re.IGNORECASE)
    # Fix "rn" -> "m" at start (e.g. "rnore" -> "more")
    text = re.sub(r'\brn(?=[aeiou])', 'm', text, flags=re.IGNORECASE)

    # --- 2. 'The' / 'That' variants ---
    # Fixes for "the" (e.g., "tbe", "tke", "tne")
    text = re.sub(r'\bt[bkn]e\b', 'the', text, flags=re.IGNORECASE) 
    text = re.sub(r'\bt[li]he\b', 'the', text, flags=re.IGNORECASE)
    text = re.sub(r'\b[li]he\b', 'the', text, flags=re.IGNORECASE)
    # Fixes for "that", "this", "those" starting with 't' or 'l'
    text = re.sub(r'\bt[li](at|is|ose)\b', r'th\1', text, flags=re.IGNORECASE)

    # --- 3. High-Frequency Specific Fixes (Safe List) ---
    # Common misreads of "and"
    text = re.sub(r'\ba[ni][li]d\b', 'and', text, flags=re.IGNORECASE) 
    # Honorifics (e.g., "Mliss" -> "Miss")
    text = re.sub(r'\bml(iss|rs|r)\b', r'M\1', text, flags=re.IGNORECASE) 
    # Specific common words
    text = re.sub(r'\bMar\.\s', 'Mr. ', text)  # Fixes Mar. 
    text = re.sub(r'\bAlr\.\s', 'Mr. ', text)  # Fixes Alr. 
    text = re.sub(r'\bMlr\.\s', 'Mr. ', text)  # Fixes Mlr. 
    text = re.sub(r'\b[fl]irst\b', 'first', text, flags=re.IGNORECASE)
    text = re.sub(r'\bhiis\b', 'his', text, flags=re.IGNORECASE)
    text = re.sub(r'\balvays\b', 'always', text, flags=re.IGNORECASE)
    text = re.sub(r'\bprogrammc\b', 'programme', text, flags=re.IGNORECASE)
    
    return text

# %%
def apply_common_ocr_patches(text):
    # Fix common title misreads
    text = re.sub(r'\bMar\.\s', 'Mr. ', text)
    text = re.sub(r'\bAlr\.\s', 'Mr. ', text) # Saw "Alr." in your output
    
    # Common miss-spellings based on frequence analysis of 
    # unidentified words from the whole dataset.
    text = re.sub(r'\balvays\b', 'always', text)

    text = re.sub(r'\banld\b', 'and', text)
    text = re.sub(r'\bnnd\b', 'and', text)
    text = re.sub(r'\bsnd\b', 'and', text)
    text = re.sub(r'\bahd\b', 'and', text)
    text = re.sub(r'\banv\b', 'and', text)

    text = re.sub(r'\bcen\b', 'been', text)
    text = re.sub(r'\becn\b', 'been', text)

    text = re.sub(r'\bflrst\b', 'first', text)
    text = re.sub(r'\blirst\b', 'first', text)

    text = re.sub(r'\birom\b', 'from', text)
    text = re.sub(r'\bfiom\b', 'from', text)
    text = re.sub(r'\bfronm\b', 'from', text)
    text = re.sub(r'\btrom\b', 'from', text)

    text = re.sub(r'\bhavc\b', 'have', text)

    text = re.sub(r'\bhiis\b', 'his', text)

    text = re.sub(r'\bmladame\b', 'madame', text)
    text = re.sub(r'\bmiadame\b', 'madame', text)

    text = re.sub(r'\bmanv\b', 'many', text)

    text = re.sub(r'\bmav\b', 'may', text)
    text = re.sub(r'\bmnay\b', 'may', text)

    text = re.sub(r'\bmnore\b', 'more', text)
    text = re.sub(r'\bnmore\b', 'more', text)

    text = re.sub(r'\bmnost\b', 'most', text)

    text = re.sub(r'\bmedtner\b', 'mother', text)

    text = re.sub(r'\bmnuch\b', 'much', text)

    text = re.sub(r'\bmlusic\b', 'music', text)
    text = re.sub(r'\bmnsic\b', 'music', text)

    text = re.sub(r'\bonlv\b', 'only', text)

    text = re.sub(r'\bplav\b', 'play', text)

    text = re.sub(r'\bplaved\b', 'played', text)

    text = re.sub(r'\bprogrammc\b', 'programme', text)

    text = re.sub(r'\bsomc\b', 'some', text)

    text = re.sub(r'\bstvle\b', 'style', text)

    text = re.sub(r'\btbat\b', 'that', text)
    text = re.sub(r'\bthlat\b', 'that', text)
    text = re.sub(r'\bthiat\b', 'that', text)
    text = re.sub(r'\btlhat\b', 'that', text)

    text = re.sub(r'\bthc\b', 'the', text)
    text = re.sub(r'\btbe\b', 'the', text)
    text = re.sub(r'\bthle\b', 'the', text)
    text = re.sub(r'\blhe\b', 'the', text)
    text = re.sub(r'\bt\'he\b', 'the', text)
    text = re.sub(r'\btthe\b', 'the', text)
    text = re.sub(r'\bthr\b', 'the', text)
    text = re.sub(r'\bfhe\b', 'the', text)

    text = re.sub(r'\bteatro\b', 'theatre', text)
    text = re.sub(r'\btbeatre\b', 'theatre', text)
    text = re.sub(r'\bthcatre\b', 'theatre', text)

    text = re.sub(r'\bthemn\b', 'them', text)
    text = re.sub(r'\bthenm\b', 'them', text)

    text = re.sub(r'\bthel\b', 'they', text)

    text = re.sub(r'\bthoso\b', 'those', text)

    text = re.sub(r'\btimc\b', 'time', text)

    text = re.sub(r'\btvo\b', 'two', text)

    text = re.sub(r'\bvcry\b', 'very', text)

    text = re.sub(r'wv', 'w', text)
    text = re.sub(r'vw', 'w', text)

    text = re.sub(r'\bwvas\b', 'was', text)
    text = re.sub(r'\bwias\b', 'was', text)

    text = re.sub(r'\bwerc\b', 'were', text)

    text = re.sub(r'\bwlhat\b', 'what', text)

    text = re.sub(r'\bvhen\b', 'when', text)
    text = re.sub(r'\bwlhen\b', 'when', text)
    text = re.sub(r'\bwben\b', 'when', text)

    text = re.sub(r'\bwvhich\b', 'which', text)
    text = re.sub(r'\bwbich\b', 'which', text)
    text = re.sub(r'\bwhicb\b', 'which', text)
    text = re.sub(r'\bwhieh\b', 'which', text)
    text = re.sub(r'\bwhichl\b', 'which', text)
    text = re.sub(r'\bwhiclh\b', 'which', text)
    text = re.sub(r'\bwhlich\b', 'which', text)
    text = re.sub(r'\bwhicl\b', 'which', text)
    text = re.sub(r'\bwhiich\b', 'which', text)
    text = re.sub(r'\bwrhich\b', 'which', text)

    text = re.sub(r'\bwlho\b', 'who', text)
    text = re.sub(r'\bvho\b', 'who', text)
    text = re.sub(r'\bwbo\b', 'who', text)
    text = re.sub(r'\bwhlo\b', 'who', text)
    text = re.sub(r'\bwhio\b', 'who', text)

    text = re.sub(r'\bwtih\b', 'with', text)
    text = re.sub(r'\bwvith\b', 'with', text)
    text = re.sub(r'\bvith\b', 'with', text)
    text = re.sub(r'\bwitb\b', 'with', text)
    text = re.sub(r'\bwithl\b', 'with', text)
    text = re.sub(r'\bwitl\b', 'with', text)

    text = re.sub(r'\bvould\b', 'would', text)

    text = re.sub(r'\bvears\b', 'years', text)

    text = re.sub(r'\bvou\b', 'you', text)

    # 690

    return text

# %% [markdown]
# ### 8. Validating Corrections
# Here we test our cleaning functions on the list of unknown words. We count how many "unknown" words are successfully transformed into "known" words (found in `COMPLETE_WORDLIST`) after applying the patches. This gives us a metric for how effective our cleaning is.

# %%
print(f"Number of words in the full corpus: {len(final_count_words)}")
misspelled_counter = Counter()
for word in final_count_words:
    cleaned_word = apply_aggressive_ocr_patches(apply_common_ocr_patches(word))
    
    if cleaned_word in COMPLETE_WORDLIST:
        continue
    
    if any([c.isdigit() for c in cleaned_word]):
        continue

    if cleaned_word.endswith("'s"):
        root_word = cleaned_word[:-2]
        if root_word in COMPLETE_WORDLIST:
            continue
    elif cleaned_word.endswith("'"):
        root_word = cleaned_word[:-1]
        if root_word in COMPLETE_WORDLIST:
            continue

    misspelled_counter.update({word : final_counts[word]})

print(f"Number of words in the misspelled set: {len(misspelled_counter.keys())}")
# Out:
# Number of words in the full corpus: 903130
# Number of words in the misspelled set: 724390

# %%
misspelled_counter.most_common()
# Out:
# [('wigmore', 7649),
#  ('mlr', 1912),
#  ('mliss', 1889),
#  ('thie', 1637),
#  ('ths', 1551),
#  ('philharmonia', 1419),
#  ('ofthe', 1235),
#  ('lso', 1141),
#  ('oi', 1067),
#  ('tle', 1060),
#  ('bechstein', 999),
#  ('ith', 953),
#  ('witlh', 911),
#  ('grotrian', 910),
#  ('und', 889),
#  ('tions', 851),
#  ('tlie', 803),
#  ('wiu', 799),
#  ('tiie', 747),
#  ('miiss', 721),
#  ('thev', 700),
#  ('perfor', 642),
#  ('www', 619),
#  ('andl', 613),
#  ('bave', 604),
#  ('craine', 597),
#  ('tre', 595),
#  ('hich', 580),
#  ('saens', 578),
#  ('heinemann', 550),
#  ('ments', 543),
#  ('unwin', 532),
#  ('glyndebourne', 527),
#  ('favourites', 517),
#  ("rachmaninov's", 513),
#  ('pettitt', 509),
#  ('rachmaninov', 506),
#  ('lpo', 488),
#  ('withi', 472),
#  ('aldwych', 449),
#  ('tive', 448),
#  ('verv', 443),
#  ('santley', 437),
#  ('mance', 434),
#  ('havo', 428),
#  ('wel', 426),
#  ('ih', 424),
#  ('eroica', 419),
#  ('gollancz', 414),
#  ('fromn', 390),
#  ('tlle', 389),
#  ('orches', 387),
#  ('thte', 386),
#  ('alr', 382),
#  ('ture', 368),
#  ('farren', 367),
#  ('aliss', 366),
#  ('ini', 364),
#  ('aldeburgh', 362),
#  ('cbso', 355),
#  ('rimsky', 352),
#  ('formance', 346),
#  ('whichi', 342),
#  ('lyttelton', 337),
#  ('chatto', 332),
#  ('produc', 332),
#  ('kingsway', 330),
#  ('hutera', 329),
#  ('titiens', 322),
#  ('chestra', 317),
#  ('watercolours', 314),
#  ('lablache', 312),
#  ('windus', 308),
#  ('pany', 306),
#  ('carnaval', 301),
#  ('ithe', 297),
#  ('sainton', 295),
#  ('abbado', 293),
#  ('musio', 289),
#  ('shc', 282),
#  ('webern', 280),
#  ('grisi', 277),
#  ('thze', 276),
#  ('symphonie', 272),
#  ('gergiev', 269),
#  ('tional', 269),
#  ('caued', 268),
#  ('bbcso', 266),
#  ('witli', 264),
#  ('froni', 260),
#  ('musi', 259),
#  ('har', 258),
#  ('menges', 258),
#  ('danc', 256),
#  ('ashkenazy', 255),
#  ('hlis', 254),
#  ('thei', 252),
#  ('tht', 250),
#  ('onegin', 250),
#  ('imr', 249),
#  ('hambourg', 248),
#  ('danse', 248),
#  ('jullien', 245),
#  ('niot', 245),
#  ('craxton', 245),
#  ('cosi', 244),
#  ('wero', 242),
#  ('elwes', 239),
#  ('sive', 239),
#  ('stabat', 238),
#  ('longmans', 238),
#  ('stil', 238),
#  ('ings', 236),
#  ('concer', 235),
#  ('liebe', 233),
#  ('symphoniques', 232),
#  ('hickox', 228),
#  ('tilson', 228),
#  ('becn', 223),
#  ('dra', 221),
#  ('nacht', 221),
#  ('ue', 220),
#  ('wav', 219),
#  ('bantock', 219),
#  ('atid', 218),
#  ('inthe', 217),
#  ('gerontius', 217),
#  ('bnt', 217),
#  ('albery', 216),
#  ('bussell', 215),
#  ('therc', 212),
#  ('morc', 211),
#  ('whioh', 210),
#  ('cottesloe', 210),
#  ('ihis', 209),
#  ('grossmith', 208),
#  ('wras', 208),
#  ('anglais', 207),
#  ('tertis', 207),
#  ('korsakov', 207),
#  ('broadwood', 206),
#  ('antd', 206),
#  ('sterndale', 205),
#  ('goupil', 204),
#  ('routledge', 203),
#  ('aad', 202),
#  ('nn', 202),
#  ('jn', 201),
#  ('choreogra', 201),
#  ('lher', 199),
#  ('stiu', 199),
#  ('thouglh', 198),
#  ('iis', 198),
#  ('choreog', 197),
#  ('knussen', 195),
#  ('atre', 193),
#  ('muti', 191),
#  ('miusic', 191),
#  ('mnusic', 190),
#  ('ters', 189),
#  ('vork', 189),
#  ('traviata', 189),
#  ('direc', 188),
#  ('masur', 188),
#  ('theni', 188),
#  ('ingly', 187),
#  ('waa', 187),
#  ('endeavours', 185),
#  ('himn', 185),
#  ('tbis', 185),
#  ('cer', 184),
#  ('newpage', 184),
#  ('mances', 184),
#  ('hle', 184),
#  ('uot', 184),
#  ('mlrs', 183),
#  ('accom', 183),
#  ('performnance', 182),
#  ('duced', 182),
#  ('certo', 182),
#  ('instru', 181),
#  ('birtwistle', 181),
#  ("d'aranyi", 180),
#  ('tirst', 179),
#  ('programnme', 179),
#  ('gardoni', 178),
#  ('norrington', 178),
#  ('thau', 177),
#  ('cowdray', 177),
#  ('courtauld', 175),
#  ('bourchier', 175),
#  ('lener', 175),
#  ('buit', 175),
#  ('secker', 175),
#  ('lhas', 174),
#  ('olian', 172),
#  ('onie', 172),
#  ('somo', 172),
#  ('liston', 170),
#  ('tte', 169),
#  ('ple', 169),
#  ('fantastique', 169),
#  ('vestris', 169),
#  ('baryshnikov', 167),
#  ('shakspeare', 167),
#  ('hobday', 167),
#  ('iti', 167),
#  ('ponsonby', 166),
#  ("webern's", 166),
#  ('deum', 166),
#  ('bintley', 165),
#  ('holborn', 165),
#  ('baddeley', 165),
#  ('sympho', 165),
#  ('steuart', 165),
#  ('blech', 164),
#  ('harrap', 163),
#  ('onl', 162),
#  ('duckworth', 162),
#  ('everv', 162),
#  ('gynt', 161),
#  ('bcen', 160),
#  ('tures', 160),
#  ("lso's", 160),
#  ('alboni', 158),
#  ('fromi', 158),
#  ('darke', 158),
#  ('trebelli', 158),
#  ('macnaghten', 157),
#  ('tennstedt', 157),
#  ('foi', 156),
#  ('tutte', 156),
#  ('executants', 156),
#  ('ameri', 156),
#  ('jansons', 155),
#  ('salonen', 155),
#  ('festi', 155),
#  ('btit', 154),
#  ('hier', 154),
#  ('lmr', 154),
#  ('xv', 154),
#  ('bir', 153),
#  ('wor', 153),
#  ('caled', 153),
#  ('mtiss', 153),
#  ('occa', 152),
#  ('petrushka', 152),
#  ('maurier', 152),
#  ('manns', 152),
#  ('vieuxtemps', 152),
#  ('dieskau', 151),
#  ('balfe', 150),
#  ('roval', 150),
#  ('liis', 150),
#  ('redfern', 150),
#  ('atnd', 150),
#  ('fron', 150),
#  ('fachiri', 150),
#  ('choreo', 150),
#  ('wieniawski', 149),
#  ('theso', 149),
#  ('nuit', 149),
#  ('seria', 149),
#  ('wvigmore', 149),
#  ('anud', 147),
#  ('nio', 147),
#  ("saens's", 147),
#  ('sonie', 146),
#  ('oae', 146),
#  ('hlall', 146),
#  ('programmne', 146),
#  ('experi', 145),
#  ('albani', 145),
#  ('hlr', 145),
#  ('ously', 144),
#  ('ayckbourn', 144),
#  ('otber', 144),
#  ('thic', 144),
#  ('contem', 143),
#  ('thre', 143),
#  ('bondstreet', 143),
#  ('wre', 143),
#  ('bostridge', 143),
#  ('chissell', 143),
#  ('sefior', 142),
#  ('leppard', 142),
#  ('suggia', 142),
#  ('fairytale', 141),
#  ('fuu', 141),
#  ('wn', 141),
#  ('phy', 140),
#  ('niglht', 140),
#  ('milnes', 140),
#  ('poeme', 140),
#  ('oramo', 139),
#  ('goehr', 137),
#  ('pancras', 137),
#  ('svmphony', 137),
#  ('wiul', 137),
#  ('repre', 137),
#  ('plaving', 137),
#  ('mackinlay', 137),
#  ('ladv', 136),
#  ('tlte', 136),
#  ('ances', 136),
#  ('mlessrs', 136),
#  ('ieolian', 135),
#  ('brosa', 135),
#  ('meisner', 135),
#  ('bles', 135),
#  ('acolian', 135),
#  ('liddell', 134),
#  ('pollini', 134),
#  ('nal', 133),
#  ("birtwistle's", 133),
#  ('oldfashioned', 133),
#  ('suc', 133),
#  ('wodehouse', 133),
#  ('livesey', 132),
#  ('ight', 132),
#  ('hawtrey', 131),
#  ('ades', 131),
#  ('trie', 131),
#  ('liall', 131),
#  ('sions', 131),
#  ('scharrer', 131),
#  ('ihc', 130),
#  ('rosenkavalier', 130),
#  ('hiall', 130),
#  ('ofa', 130),
#  ('schu', 130),
#  ('timesonline', 130),
#  ('perahia', 129),
#  ('tothe', 129),
#  ('patey', 129),
#  ('asd', 129),
#  ('suddaby', 128),
#  ('niore', 128),
#  ('lhave', 128),
#  ('porary', 127),
#  ('slatkin', 127),
#  ('mfiss', 127),
#  ('seo', 127),
#  ('haffner', 127),
#  ('vio', 126),
#  ('irst', 126),
#  ('matic', 126),
#  ('firt', 126),
#  ('oth', 125),
#  ('ists', 125),
#  ('pauer', 124),
#  ('ilr', 124),
#  ('glazounov', 124),
#  ('caradori', 124),
#  ('rozhdestvensky', 123),
#  ('tio', 123),
#  ('publio', 123),
#  ('camo', 123),
#  ('tf', 122),
#  ('florestan', 122),
#  ('lohr', 122),
#  ('erard', 121),
#  ('emo', 121),
#  ('irae', 121),
#  ('kylian', 121),
#  ('alnd', 121),
#  ('viardot', 121),
#  ('bythe', 121),
#  ('conduc', 120),
#  ('ered', 120),
#  ('ancd', 120),
#  ('jarvi', 120),
#  ('splendours', 120),
#  ('gatti', 119),
#  ('orloff', 119),
#  ('pher', 119),
#  ('briliant', 119),
#  ('wozzeck', 119),
#  ('orpen', 119),
#  ('iiis', 119),
#  ('vengerov', 119),
#  ('llr', 119),
#  ('liebestod', 119),
#  ('sinopoli', 118),
#  ('satur', 118),
#  ('dunhill', 118),
#  ('lthe', 118),
#  ('thoe', 118),
#  ('impres', 117),
#  ('slhe', 117),
#  ('fbr', 117),
#  ('bettini', 117),
#  ('musgrave', 117),
#  ('boughton', 117),
#  ('hannen', 117),
#  ('thoughi', 117),
#  ('apd', 116),
#  ('robey', 116),
#  ('maior', 116),
#  ('schnittke', 116),
#  ('lhis', 116),
#  ('inore', 116),
#  ('tavener', 116),
#  ('storv', 116),
#  ('whe', 116),
#  ('swi', 116),
#  ('alwavs', 115),
#  ('miore', 115),
#  ("d'amore", 115),
#  ('petipa', 115),
#  ('bruton', 115),
#  ('maltings', 114),
#  ('tban', 114),
#  ('andt', 114),
#  ('thec', 114),
#  ('amore', 114),
#  ('commedia', 114),
#  ('larly', 114),
#  ('thlis', 114),
#  ('hn', 113),
#  ('somie', 113),
#  ('mnade', 113),
#  ('mukhamedov', 112),
#  ('exceuent', 112),
#  ('fre', 112),
#  ('wliich', 112),
#  ('malvolio', 112),
#  ('tlho', 112),
#  ('philhar', 112),
#  ("th'e", 111),
#  ('brixton', 111),
#  ('symphonv', 111),
#  ('jurowski', 111),
#  ('tral', 111),
#  ('mdue', 111),
#  ('particu', 111),
#  ('ght', 110),
#  ('progranmme', 110),
#  ('expres', 110),
#  ('brabbins', 109),
#  ("korsakov's", 109),
#  ('pekka', 109),
#  ('goodall', 109),
#  ('goolden', 109),
#  ("d'affaires", 109),
#  ('fitzwilliam', 109),
#  ('jefferies', 109),
#  ('ozawa', 109),
#  ('likc', 108),
#  ('ilis', 108),
#  ('thl', 108),
#  ('excelent', 108),
#  ('dyall', 108),
#  ("bintley's", 108),
#  ('uo', 108),
#  ('ffrangcon', 108),
#  ('coun', 108),
#  ('tavistock', 108),
#  ('godot', 108),
#  ('wbat', 107),
#  ('boheme', 107),
#  ("i'he", 107),
#  ('ancl', 107),
#  ('isserlis', 107),
#  ('whi', 107),
#  ('turnage', 107),
#  ('sarasate', 107),
#  ("philharmonia's", 106),
#  ('forthe', 106),
#  ('voi', 106),
#  ('societv', 106),
#  ('thesiger', 106),
#  ('lowther', 106),
#  ('coneert', 106),
#  ('tq', 106),
#  ('arnd', 105),
#  ('ences', 105),
#  ('atthe', 105),
#  ('oj', 105),
#  ('thes', 105),
#  ('froin', 105),
#  ('dramatio', 105),
#  ('plavers', 105),
#  ('wigmnore', 105),
#  ('performanco', 105),
#  ('smau', 105),
#  ('tained', 104),
#  ('andthe', 104),
#  ('chaillet', 104),
#  ('formances', 104),
#  ('schaufuss', 104),
#  ('cellier', 104),
#  ('whicli', 104),
#  ('vous', 104),
#  ('kutcher', 104),
#  ('xenakis', 103),
#  ('marylebone', 103),
#  ('itn', 103),
#  ('fau', 102),
#  ('whic', 102),
#  ('alid', 102),
#  ('winterreise', 102),
#  ('littlo', 102),
#  ('flne', 102),
#  ('compa', 102),
#  ('aii', 102),
#  ('fromii', 102),
#  ('smeterlin', 101),
#  ('jarrolds', 101),
#  ('companv', 101),
#  ('somervell', 101),
#  ('certs', 101),
#  ('bauet', 101),
#  ('inito', 101),
#  ('thit', 100),
#  ('tation', 100),
#  ('inot', 100),
#  ('ihat', 100),
#  ('nlr', 100),
#  ('whicih', 100),
#  ('ood', 100),
#  ('vieni', 100),
#  ('boosey', 99),
#  ('ttie', 99),
#  ('kentner', 99),
#  ('vear', 99),
#  ('grinke', 99),
#  ('wrho', 99),
#  ('niusic', 98),
#  ('enb', 98),
#  ('heldenleben', 98),
#  ('finzi', 97),
#  ('reauy', 97),
#  ('tfie', 97),
#  ('sented', 97),
#  ('chailly', 97),
#  ('glocester', 97),
#  ('teyte', 97),
#  ('fricker', 96),
#  ('odile', 96),
#  ('mnight', 96),
#  ('distin', 96),
#  ('thesc', 96),
#  ('gyorgy', 96),
#  ('beeu', 96),
#  ('bejart', 96),
#  ('mahlerian', 95),
#  ('mcinnes', 95),
#  ('wlhichl', 95),
#  ('qeh', 95),
#  ('thn', 95),
#  ('musik', 95),
#  ('blagrove', 95),
#  ("balfe's", 95),
#  ('saturdav', 95),
#  ('harker', 95),
#  ('mlonday', 94),
#  ('irek', 94),
#  ('wlth', 94),
#  ('miere', 94),
#  ('wihich', 94),
#  ('lascelles', 94),
#  ('bril', 94),
#  ("goehr's", 94),
#  ('wigniore', 94),
#  ('niost', 93),
#  ('theatregoers', 93),
#  ('ofi', 93),
#  ('mrr', 93),
#  ('mesmerising', 93),
#  ('manen', 93),
#  ('pieco', 93),
#  ('wheni', 93),
#  ('standchen', 93),
#  ('norgate', 93),
#  ('cusins', 92),
#  ('ral', 92),
#  ('austro', 92),
#  ('catterall', 92),
#  ('comedv', 92),
#  ('cundell', 92),
#  ('ernani', 92),
#  ('thcse', 92),
#  ('mnany', 92),
#  ('lic', 92),
#  ('uf', 92),
#  ('comedie', 92),
#  ('beringer', 92),
#  ('ional', 92),
#  ('francaise', 92),
#  ('concertgoers', 91),
#  ('mninor', 91),
#  ('anad', 91),
#  ('tchehov', 91),
#  ('wilh', 91),
#  ('pathetique', 91),
#  ('eighteenthcentury', 91),
#  ('tively', 90),
#  ('sawallisch', 90),
#  ('coriolan', 90),
#  ('lockey', 90),
#  ('voung', 90),
#  ('witi', 90),
#  ('plg', 90),
#  ('plavs', 90),
#  ('hls', 90),
#  ('througlh', 90),
#  ('pagliacci', 89),
#  ('firom', 89),
#  ('cherkassky', 89),
#  ('ces', 89),
#  ('makarova', 89),
#  ('dowton', 89),
#  ('mies', 89),
#  ('aolian', 89),
#  ('miost', 89),
#  ('performanice', 89),
#  ('cou', 89),
#  ('eddison', 89),
#  ('donohoe', 89),
#  ('belohlavek', 89),
#  ('ove', 89),
#  ('mukle', 89),
#  ('bers', 88),
#  ('otlher', 88),
#  ('perbaps', 88),
#  ('hawkes', 88),
#  ('albans', 88),
#  ('perfornance', 88),
#  ('batti', 88),
#  ('samo', 88),
#  ('ents', 88),
#  ('mezza', 88),
#  ('mlozart', 88),
#  ('vithout', 88),
#  ('ganz', 88),
#  ('mdr', 88),
#  ("ayckbourn's", 88),
#  ('tnd', 88),
#  ('wvitlh', 88),
#  ('lumley', 88),
#  ('lazarev', 88),
#  ('beeni', 88),
#  ('beetho', 87),
#  ('hias', 87),
#  ('phillpotts', 87),
#  ('beea', 87),
#  ('wth', 87),
#  ('petruchio', 87),
#  ('jeune', 87),
#  ('brunskill', 87),
#  ('vhat', 87),
#  ('tradi', 86),
#  ('vhile', 86),
#  ('beon', 86),
#  ('staudigl', 86),
#  ('vorks', 86),
#  ('bhuller', 86),
#  ('showbiz', 86),
#  ('imiss', 86),
#  ('tlheatre', 86),
#  ('mercutio', 86),
#  ('alun', 86),
#  ('tomor', 86),
#  ('thbe', 86),
#  ('ilie', 86),
#  ('wcre', 86),
#  ('sonme', 86),
#  ('especialy', 86),
#  ('hampson', 85),
#  ('wiith', 85),
#  ('ohe', 85),
#  ('smal', 85),
#  ('lhad', 85),
#  ('generauy', 85),
#  ('pavarotti', 85),
#  ('himnself', 85),
#  ('hogwood', 84),
#  ('pletnev', 84),
#  ('wih', 84),
#  ('tainly', 84),
#  ('wili', 84),
#  ('mous', 84),
#  ('seene', 84),
#  ('miessrs', 84),
#  ('wiginore', 84),
#  ('thrce', 84),
#  ('warburg', 84),
#  ('rummel', 84),
#  ('athole', 84),
#  ('spottiswoode', 84),
#  ('ze', 84),
#  ('reat', 83),
#  ('hini', 83),
#  ('semiquavers', 83),
#  ('mnake', 83),
#  ("musgrave's", 83),
#  ('speaight', 83),
#  ('rary', 83),
#  ('suchi', 83),
#  ('spitalfields', 83),
#  ('thiis', 83),
#  ('aot', 83),
#  ('tbree', 83),
#  ('ivimey', 83),
#  ('vay', 83),
#  ('tbough', 83),
#  ('burnand', 83),
#  ('conccrt', 83),
#  ('carreno', 82),
#  ('hil', 82),
#  ('onily', 82),
#  ('blr', 82),
#  ('cism', 82),
#  ('tme', 82),
#  ('sorne', 82),
#  ('israels', 82),
#  ('giuglini', 82),
#  ('billington', 82),
#  ('threo', 82),
#  ('notting', 82),
#  ('tauber', 82),
#  ('thet', 82),
#  ('raphy', 82),
#  ('contempo', 82),
#  ('bhe', 82),
#  ('widdop', 82),
#  ('vignoles', 82),
#  ("knussen's", 82),
#  ('iast', 82),
#  ('liave', 82),
#  ('glock', 82),
#  ('npon', 82),
#  ('nith', 81),
#  ('tbere', 81),
#  ('benno', 81),
#  ('andc', 81),
#  ('gewandhaus', 81),
#  ('kleine', 81),
#  ('betveen', 81),
#  ('tlhis', 81),
#  ('soine', 81),
#  ('rubini', 81),
#  ('kertesz', 81),
#  ('theatrc', 81),
#  ('orchcstra', 81),
#  ('noces', 81),
#  ('performanee', 81),
#  ('iiot', 81),
#  ('fes', 81),
#  ('forza', 81),
#  ('welser', 81),
#  ('atten', 81),
#  ('pouishnoff', 80),
#  ('gatty', 80),
#  ('oif', 80),
#  ("petipa's", 80),
#  ('gauery', 80),
#  ('rignold', 80),
#  ('ied', 80),
#  ('ncw', 80),
#  ('furtwangler', 80),
#  ('thiere', 80),
#  ('brangwyn', 80),
#  ('tery', 80),
#  ('sothern', 80),
#  ('atd', 80),
#  ('muisic', 80),
#  ('nliss', 80),
#  ('nabucco', 79),
#  ("tavener's", 79),
#  ('miay', 79),
#  ('zoltan', 79),
#  ('ceived', 79),
#  ('balet', 79),
#  ('whicil', 79),
#  ("mlozart's", 79),
#  ('coyne', 79),
#  ('wai', 79),
#  ('jobn', 79),
#  ('lik', 79),
#  ('tured', 79),
#  ('orcbestra', 79),
#  ('musique', 79),
#  ('farjeon', 79),
#  ('xvith', 78),
#  ('holme', 78),
#  ('tliat', 78),
#  ('samne', 78),
#  ('heaney', 78),
#  ('clas', 78),
#  ('mlary', 78),
#  ('rostal', 78),
#  ('merivale', 78),
#  ('thern', 78),
#  ('theatbe', 78),
#  ('progranime', 78),
#  ('exhibitioni', 78),
#  ('especiauy', 78),
#  ("bantock's", 78),
#  ('mnd', 78),
#  ('jeyasingh', 77),
#  ('hammerklavier', 77),
#  ('malleson', 77),
#  ('ibe', 77),
#  ('euston', 77),
#  ('ily', 77),
#  ('hinm', 77),
#  ('wessely', 77),
#  ('bournonville', 77),
#  ("finzi's", 77),
#  ('slie', 77),
#  ('centurv', 77),
#  ('mnr', 77),
#  ('joln', 77),
#  ('kennington', 77),
#  ('kennerley', 77),
#  ('nighit', 77),
#  ('ondon', 77),
#  ('hodson', 77),
#  ('lished', 77),
#  ("d'oyly", 77),
#  ('nade', 76),
#  ('realy', 76),
#  ('yoshida', 76),
#  ('hig', 76),
#  ('barbiere', 76),
#  ('thoy', 76),
#  ('trhe', 76),
#  ('tto', 76),
#  ('sylphide', 76),
#  ('marriner', 76),
#  ('quayle', 76),
#  ('almaviva', 76),
#  ('cherubino', 76),
#  ('picce', 76),
#  ('cour', 75),
#  ('wns', 75),
#  ('thbatre', 75),
#  ('casella', 75),
#  ('iust', 75),
#  ('bimself', 75),
#  ('oin', 75),
#  ('horenstein', 75),
#  ('ivas', 75),
#  ('madamo', 75),
#  ('samsova', 75),
#  ('muchi', 75),
#  ('cenerentola', 75),
#  ('amina', 75),
#  ('thp', 75),
#  ('fellowes', 75),
#  ('rothenstein', 75),
#  ('clunes', 75),
#  ("jullien's", 75),
#  ('courtneidge', 75),
#  ('chenil', 75),
#  ('theatr', 75),
#  ('benois', 75),
#  ('guished', 75),
#  ('fistoulari', 75),
#  ('gieves', 75),
#  ('katchen', 75),
#  ('cornhill', 74),
#  ('tage', 74),
#  ('mckellen', 74),
#  ('thq', 74),
#  ('herz', 74),
#  ('sbould', 74),
#  ('anrd', 74),
#  ("fricker's", 74),
#  ('wlio', 74),
#  ('tlhere', 74),
#  ('symnphony', 74),
#  ('shau', 74),
#  ('tamburini', 74),
#  ('tly', 74),
#  ('mnst', 74),
#  ('hudd', 74),
#  ('ailesbury', 74),
#  ('bagot', 74),
#  ('maryinsky', 74),
#  ('sioned', 74),
#  ('rst', 74),
#  ('takemitsu', 73),
#  ('grcat', 73),
#  ('tlze', 73),
#  ("of'the", 73),
#  ('hiim', 73),
#  ('memoriam', 73),
#  ('silvestri', 73),
#  ('liko', 73),
#  ('rapher', 73),
#  ('hmr', 73),
#  ('dence', 73),
#  ('gollanez', 73),
#  ('sivori', 73),
#  ('tombeau', 73),
#  ('carreras', 73),
#  ('sinden', 73),
#  ('ivith', 73),
#  ('rosmer', 72),
#  ('christus', 72),
#  ('whilo', 72),
#  ('leporello', 72),
#  ('passagework', 72),
#  ('lonesco', 72),
#  ('jeolian', 72),
#  ('miary', 72),
#  ('knollys', 72),
#  ('mnust', 72),
#  ('hea', 72),
#  ('cial', 72),
#  ('temirkanov', 72),
#  ('cerito', 72),
#  ('wigrnore', 72),
#  ('sono', 72),
#  ('uch', 72),
#  ('iir', 72),
#  ('ished', 72),
#  ('niew', 72),
#  ('thst', 72),
#  ('audienco', 72),
#  ('londoni', 72),
#  ("d'or", 72),
#  ('alreadv', 71),
#  ('madc', 71),
#  ('ackland', 71),
#  ('terfel', 71),
#  ('quartermaine', 71),
#  ('thafs', 71),
#  ('mlay', 71),
#  ('ater', 71),
#  ('iar', 71),
#  ('orehestra', 71),
#  ('connexions', 71),
#  ('belletti', 71),
#  ('faucit', 71),
#  ('thse', 71),
#  ('timnes', 71),
#  ('molique', 71),
#  ('salmond', 71),
#  ('usic', 71),
#  ('woould', 71),
#  ('kreisleriana', 71),
#  ('sylphides', 71),
#  ('mezzosoprano', 71),
#  ('gertler', 71),
#  ('kilburn', 71),
#  ('borwick', 71),
#  ('cially', 70),
#  ('pougnet', 70),
#  ('theatro', 70),
#  ("kylian's", 70),
#  ('haendel', 70),
#  ('lympany', 70),
#  ('whici', 70),
#  ('wynyard', 70),
#  ('nozze', 70),
#  ('giv', 70),
#  ('edwardes', 70),
#  ('swinley', 70),
#  ('ouly', 70),
#  ('gf', 70),
#  ('royde', 70),
#  ('rojo', 70),
#  ('niight', 70),
#  ('worlk', 70),
#  ('owni', 70),
#  ('ratlher', 70),
#  ('sional', 70),
#  ('yarde', 70),
#  ('brownlow', 70),
#  ('miserables', 70),
#  ('hallis', 70),
#  ('ofl', 70),
#  ('cven', 70),
#  ('coote', 70),
#  ('persiani', 70),
#  ('gerster', 70),
#  ('froml', 70),
#  ('vitali', 69),
#  ('pirani', 69),
#  ('wiho', 69),
#  ('firstrate', 69),
#  ('zart', 69),
#  ('lous', 69),
#  ('fouowed', 69),
#  ("turnage's", 69),
#  ('vezin', 69),
#  ('whlch', 69),
#  ('wom', 69),
#  ('amnong', 69),
#  ('thougb', 69),
#  ('sympbony', 69),
#  ("manen's", 69),
#  ('noth', 69),
#  ('ehe', 69),
#  ('ruh', 69),
#  ('foli', 69),
#  ...]
